# %%
import openpyxl
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import pandas as pd
import os

# %% [markdown]
# ### Data Scaling

# %%
data = pd.read_csv('C:/Users/chsjk/OneDrive/Documents/MATLAB/drtoolbox/TOLz.csv')
username = np.array([data.username]).squeeze() #학생 이름
pca1 = np.array([data['pc1']]).T
pca2 = np.array([data['pc2']]).T
pca3 = np.array([data['pc3']]).T
X = np.hstack((pca1,pca2,pca3))  #학생 데이터. (22,3)
y = np.array(data.target)
feature_names = np.array([['pc1','pc2','pc3']])

# %% [markdown]
# ### Use Korean in Matplotlib

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
import matplotlib.font_manager as fm

font_location = 'C:/Windows/Fonts/H2GTRM.TTF' 
font_name = fm.FontProperties(fname = font_location).get_name()
mpl.rc('font', family = font_name)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state = 0)
psych_tsne = tsne.fit_transform(X)

plt.figure(figsize = (10,10))
plt.xlim(psych_tsne[:,0].min()-1, psych_tsne[:,0].max()+1)
plt.ylim(psych_tsne[:,1].min()-1, psych_tsne[:,1].max()+1)
string = range(psych_tsne.shape[0])

for i in range(psych_tsne.shape[0]):
    plt.text(psych_tsne[i,0], psych_tsne[i,1], username[i], fontdict = {'weight':'bold','size':'9'})
plt.xlabel('t-sne feature 0')
plt.ylabel('t-sne feature 1')
# Out:
# Text(0,0.5,'t-sne feature 1')
